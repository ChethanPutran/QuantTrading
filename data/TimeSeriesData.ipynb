# %% [markdown]
# ### Data sources
# #### 1. Foreign
# 1. Quandl
# 2. IEX Finance
# 3. Yaho finance
# #### 2. Indian
# 1. NSEpy

# %%
import matplotlib.pyplot as plt
import pandas as pd
from nsepy import get_history
from pandas_datareader import data
from datetime import date

# %%
# Indian stock exchange data
data = get_history(symbol="BHARTIARTL", start=date(2025,1,1), end=date(2025,1,31))
data
# Out:
# Empty DataFrame
# Columns: [Symbol, Series, Prev Close, Open, High, Low, Last, Close, VWAP, Volume, Turnover, Trades, Deliverable Volume, %Deliverble]
# Index: []

# %%
sbin = get_history(symbol='SBIN',
                   start=date(2015,1,1),
                   end=date(2015,1,10))

# %%
sbin
